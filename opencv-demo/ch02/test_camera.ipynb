# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
cap = cv2.VideoCapture(0)

# %%
ret = cap.set(3, 640)
ret = cap.set(4, 480)

# %%
plt.ion()

# %%
while cap.isOpened():
    ret, frame = cap.read()
    plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
#     plt.show()
    plt.show(block=False)#可选
    plt.pause(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-d0953a041827> in <module>
#       4 #     plt.show()
#       5     plt.show(block=False)#可选
# ----> 6     plt.pause(1)
#
# ~/.cv2/lib/python3.6/site-packages/matplotlib/pyplot.py in pause(interval)
#     310         canvas.start_event_loop(interval)
#     311     else:
# --> 312         time.sleep(interval)
#     313
#     314
#
# KeyboardInterrupt:
